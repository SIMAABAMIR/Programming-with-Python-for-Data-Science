# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module2 - Lab4

# %% [markdown]
# ## Lab Assignment 4
# Navigate over to [ESPN's website for NHL Historic Player Points Statistics](http://www.espn.com/nhl/statistics/player/_/stat/points/sort/points/year/2015/seasontype/2), for the years 2014-2015. This page has a table on it with a few stats we're interested in obtaining. But it's a bit messy! Clean it up for us, using the appropriate commands to:
#
# <ol>
# <li>Load up the table on <b>just this page</b> into a Pandas dataframe. No need to worry about the other pages!</li>
# <li>Rename the columns so that they match the column definitions on the website.</li>
# <li>Get rid of (drop) any erroneous rows that has at least 4 NANs in them.</li>
# <li>Get rid of the <b>RK</b> column.</li>
# <li>Ensure there are no nan "holes" in your index.</li>
# <li>Check the dtypes of all columns, and ensure those that should be numeric are numeric.</li>
# </ol>

# %% [markdown]
# Import and alias Pandas:

# %%
# .. your code here ..
import pandas as pd

# %% [markdown]
# Load up the table from the link, and extract the dataset out of it. If you're having issues with this, look carefully at the sample code provided in the reading:

# %%
# .. your code here ..
df=pd.read_html('http://www.espn.com/nhl/statistics/player/_/stat/points/sort/points/year/2015/seasontype/2',header=1)[0]
df.head()
# Out:
#     RK             PLAYER TEAM  GP   G   A PTS +/- PIM PTS/G  SOG   PCT GWG  \
# 0    1     Jamie Benn, LW  DAL  82  35  52  87   1  64  1.06  253  13.8   6
# 1    2    John Tavares, C  NYI  82  38  48  86   5  46  1.05  278  13.7   8
# 2    3   Sidney Crosby, C  PIT  77  28  56  84   5  47  1.09  237  11.8   3
# 3    4  Alex Ovechkin, LW  WSH  81  53  28  81  10  58  1.00  395  13.4  11
# 4  NaN  Jakub Voracek, RW  PHI  82  22  59  81   1  78  0.99  221  10.0   3
#
#   G.1 A.1 G.2 A.2
# 0  10  13   2   3
# 1  13  18   0   1
# 2  10  21   0   0
# 3  25   9   0   0
# 4  11  22   0   0

# %% [markdown]
# Next up, rename the columns so that they are _similar_ to the column definitions provided to you on the website. Be careful and don't accidentally use any column names twice. If a column uses special characters, you can replace them with regular characters to make it easier to work with:

# %%
# .. your code here ..
df.columns=['RK', 'Player', 'Team', 'Games Played', 'Goals', 'Assists',
             'Points', 'Plus/Minus Rating', 'Penalty Minutes',
             'Points Per Game', 'Shots on Goal', 'Shooting Percentage',
             'Game-Winning Goals', 'Power-Play Goals', 'Power-Play Assists',
             'Short-Handed Goals', 'Short-Handed Assists']
df.head()
# Out:
#     RK             Player Team Games Played Goals Assists Points  \
# 0    1     Jamie Benn, LW  DAL           82    35      52     87
# 1    2    John Tavares, C  NYI           82    38      48     86
# 2    3   Sidney Crosby, C  PIT           77    28      56     84
# 3    4  Alex Ovechkin, LW  WSH           81    53      28     81
# 4  NaN  Jakub Voracek, RW  PHI           82    22      59     81
#
#   Plus/Minus Rating Penalty Minutes Points Per Game Shots on Goal  \
# 0                 1              64            1.06           253
# 1                 5              46            1.05           278
# 2                 5              47            1.09           237
# 3                10              58            1.00           395
# 4                 1              78            0.99           221
#
#   Shooting Percentage Game-Winning Goals Power-Play Goals Power-Play Assists  \
# 0                13.8                  6               10                 13
# ...

# %% [markdown]
# Get rid of any row that has at least 4 NANs in it. That is, any rows that do not contain player points statistics:

# %%
# .. your code here ..
# df.dropna?
df=df.dropna(axis=0,thresh=4)
len(df)
# Out:
# 43

# %% [markdown]
# At this point, look through your dataset by printing it. There probably still are some erroneous rows in there. What indexing command(s) will you use to select all rows EXCEPT those rows?

# %%
df.drop([11,23,35],axis=0,inplace=True)
len(df)
# Out:
# 40

# %%
# .. your code here ..
# df.drop?
len(df[df['Player'] !='PLAYER'])
df.head()
# Out:
#     RK             Player Team Games Played Goals Assists Points  \
# 0    1     Jamie Benn, LW  DAL           82    35      52     87
# 1    2    John Tavares, C  NYI           82    38      48     86
# 2    3   Sidney Crosby, C  PIT           77    28      56     84
# 3    4  Alex Ovechkin, LW  WSH           81    53      28     81
# 4  NaN  Jakub Voracek, RW  PHI           82    22      59     81
#
#   Plus/Minus Rating Penalty Minutes Points Per Game Shots on Goal  \
# 0                 1              64            1.06           253
# 1                 5              46            1.05           278
# 2                 5              47            1.09           237
# 3                10              58            1.00           395
# 4                 1              78            0.99           221
#
#   Shooting Percentage Game-Winning Goals Power-Play Goals Power-Play Assists  \
# 0                13.8                  6               10                 13
# ...

# %% [markdown]
# Get rid of the 'RK' column:

# %%
# .. your code here ..
# df.drop?
df=df.drop(labels=['RK'], axis=1)
df.head()
# Out:
#               Player Team Games Played Goals Assists Points Plus/Minus Rating  \
# 0     Jamie Benn, LW  DAL           82    35      52     87                 1
# 1    John Tavares, C  NYI           82    38      48     86                 5
# 2   Sidney Crosby, C  PIT           77    28      56     84                 5
# 3  Alex Ovechkin, LW  WSH           81    53      28     81                10
# 4  Jakub Voracek, RW  PHI           82    22      59     81                 1
#
#   Penalty Minutes Points Per Game Shots on Goal Shooting Percentage  \
# 0              64            1.06           253                13.8
# 1              46            1.05           278                13.7
# 2              47            1.09           237                11.8
# 3              58            1.00           395                13.4
# 4              78            0.99           221                10.0
#
#   Game-Winning Goals Power-Play Goals Power-Play Assists Short-Handed Goals  \
# ...

# %% [markdown]
# Make sure there are no holes in your index by resetting it. There is an example of this in the reading material. By the way, drop the original index.

# %%
# .. your code here ..
len(df)
# df.reset_index?
# df.reset_index(drop=True,inplace=True)
df=df.reset_index(drop=True)

# %% [markdown]
# Check the data type of all columns, and ensure those that should be numeric are numeric.

# %%
# .. your code here ..
df.dtypes
# Out:
# Player                  object
# Team                    object
# Games Played            object
# Goals                   object
# Assists                 object
# Points                  object
# Plus/Minus Rating       object
# Penalty Minutes         object
# Points Per Game         object
# Shots on Goal           object
# Shooting Percentage     object
# Game-Winning Goals      object
# Power-Play Goals        object
# Power-Play Assists      object
# Short-Handed Goals      object
# Short-Handed Assists    object
# dtype: object

# %%
len_col=len(df.columns)
# pd.to_numeric?
for i in range(2,len_col):
    df.iloc[:,i]=pd.to_numeric(df.iloc[:,i], errors='coerce')
    
df.dtypes
# Out:
# Player                   object
# Team                     object
# Games Played              int64
# Goals                     int64
# Assists                   int64
# Points                    int64
# Plus/Minus Rating         int64
# Penalty Minutes           int64
# Points Per Game         float64
# Shots on Goal             int64
# Shooting Percentage     float64
# Game-Winning Goals        int64
# Power-Play Goals          int64
# Power-Play Assists        int64
# Short-Handed Goals        int64
# Short-Handed Assists      int64
# dtype: object

# %% [markdown]
# Your dataframe is now ready! Use the appropriate commands to answer the questions on the course lab page.

# %% [markdown]
# ## Lab Questions

# %%
df.head(20)
# Out:
#                     Player Team  Games Played  Goals  Assists  Points  \
# 0           Jamie Benn, LW  DAL            82     35       52      87
# 1          John Tavares, C  NYI            82     38       48      86
# 2         Sidney Crosby, C  PIT            77     28       56      84
# 3        Alex Ovechkin, LW  WSH            81     53       28      81
# 4        Jakub Voracek, RW  PHI            82     22       59      81
# 5     Nicklas Backstrom, C  WSH            82     18       60      78
# 6          Tyler Seguin, C  DAL            71     37       40      77
# 7          Jiri Hudler, LW  CGY            78     31       45      76
# 8         Daniel Sedin, LW  VAN            82     20       56      76
# 9   Vladimir Tarasenko, RW  STL            77     37       36      73
# 10        Nick Foligno, LW  CBJ            79     31       42      73
# 11        Claude Giroux, C  PHI            81     25       48      73
# ...

# %%
#After completing the 6 steps above, how many rows remain in this dataset? (Not to be confused with the index!)

print(len(df))
#40

#How many unique PCT values exist in the table?
print(len(df['Shooting Percentage'].unique()))
#36

#What is the value you get by adding the GP values at indices 15 and 16 of this table?

add_GP=df.loc[15,'Games Played'] + df.loc[16,'Games Played']
print(add_GP)
#164
# Out:
# 40
# 36
# 164
